# %% [markdown]
# EXERCICE TEST DE BASTHON : fichier externe csv, modules Pandas et Matplotlib, clients Vauban élèves et prof
#
# Pour charger un csv, il suffit de cliquer sur le bouton ouvrir (icone dossier) !

# %% [markdown]
# 1) Importer les modules Python et le sous-module pyplot de matplotlib sous leurs alias usuels.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 2) Importer le fichier netflix.csv dans un Dataframe nommé df. Afficher les cinq premières entrées du tableau.

# %%
df = pd.read_csv("netflix.csv")
df.head()
# Out:
#   show_id  ...                                        description
# 0      s1  ...  As her father nears the end of his life, filmm...
# 1      s2  ...  After crossing paths at a party, a Cape Town t...
# 2      s3  ...  To protect his family from a powerful drug lor...
# 3      s4  ...  Feuds, flirtations and toilet talk go down amo...
# 4      s5  ...  In a city of coaching centers known to train I...
#
# [5 rows x 12 columns]

# %% [markdown]
# 3) Tracer l'histogramme du nombre de films présents dans le catalogue par année de sortie.

# %%
plt.hist(df.release_year)
plt.show()
